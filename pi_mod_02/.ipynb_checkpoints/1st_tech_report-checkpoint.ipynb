# %% [markdown]
# ### Reporte Técnico
#
# ## Sección: Análisis de la Tabla Usuarios
#
# Reporte de hallazgos – Tabla Usuarios
# 1. Principales insights y problemas encontrados
#
# | Columna         | Tipo de dato | Descripción                   | Observaciones           |
# | --------------- | ------------ | ----------------------------- | ----------------------- |
# | UsuarioID       | integer      | Identificador único           | Clave primaria          |
# | Nombre          | string       | Nombre completo               | Sin valores nulos       |
# | Email           | string       | Email del usuario             | Unicidad no validada    |
# | Fecha_Registro  | date         | Fecha de creación del usuario | Valor default detectado |
#
#
# 1.2. Problemas detectados
# El campo fecha_registro contiene valores por defecto, sin variabilidad → no confiable.
#
# No hay validación de unicidad en email → puede haber duplicados.
#
# No se detectan valores nulos, pero hay columnas que podrían necesitar estandarización (por ejemplo, nombres en distintos formatos).
#
# 1.3. Decisiones tomadas
# Eliminar fecha_registro del análisis temporal. Considerar validacions ycotrol al ingresar nuevos datos para obtner informaciñón
#
# Considerar normalizar nombres en etapas posteriores si se requiere análisis por usuario.
#
# A futuro, revisar la fuente de datos o pipeline que genera fecha_registro.
#
# 1.4. Consultas relevantes aplicadas
# Usuarios registrados por mes: ❌ Consulta descartada por datos inválidos.
# suarios con más de una orden:
# - **999 de 1000 usuarios** realizaron más de una orden.
# - **10.000 órdenes** en total, lo cual indica una alta tasa de recurrencia.
# Uusarios que aun no compran 1 de mil registraods. Existe una conversión prácticamente total de registros a compradores, lo que **indica una adquisición de usuarios muy efectiva**.
# Usuarios con mayor gasto total
# Se identificaron los 10 usuarios con mayor gasto acumulado en órdenes. El monto total gastado por estos usuarios ronda los 30 mil , lo cual implica un comportamiento significativamente superior al promedio general de gasto por orden.
#
# 🔍 Análisis comparativo:
# El total promedio por orden es de $507,76, con una mediana de $506,80, lo que sugiere una distribución simétrica.
#
# El valor máximo observado en una orden individual es de $999,99, lo cual representa el tope permitido en el sistema.
#
# El gasto acumulado de los usuarios top (~$30.000) indica que han realizado al menos entre 30 y 60 órdenes, si consideramos los valores promedio y máximo.
#
# Esto sugiere una alta recurrencia de compra entre los usuarios top, lo cual podría ser útil para:
#
# Identificar patrones de fidelidad.
#
# Evaluar oportunidades de programas de beneficios o segmentación avanzada.

# %%
from app.utils import plot_utils,postgres_utils


query = """
SELECT "UsuarioID", SUM("Total") AS "GastoTotal"
FROM "Ordenes"
GROUP BY "UsuarioID"
ORDER BY "GastoTotal" DESC
LIMIT 10
"""

postgres_utils.run_query(query)
# Out:
#    UsuarioID  GastoTotal
# 0        411    32342.70
# 1        379    32341.14
# 2        951    32152.02
# 3         25    31643.07
# 4        382    31487.88
# 5        878    30877.86
# 6         15    30336.87
# 7        390    30298.62
# 8        913    29765.79
# 9        892    29654.55

# %%
from app.utils import plot_utils,postgres_utils


query = """
SELECT "UsuarioID", SUM("Total") AS "GastoTotal"
FROM "Ordenes"
GROUP BY "UsuarioID"
ORDER BY "GastoTotal" DESC
LIMIT 10
"""

top_gastadores_df = postgres_utils.run_query(query)

plot_utils.plot_top_bar_chart(
    df=top_gastadores_df,
    x_column='UsuarioID',
    y_column='GastoTotal',
    plot_title="Top 10 usuarios por gasto total",
    x_label="Usuario ID",
    y_label="Gasto acumulado",
    top_n=10,
    figsize=(20, 8)
)

# %% [markdown]
# Transformaciones globales
# (Aplica si hiciste modificaciones estructurales o agregaste tablas derivadas) Aca creo que sugeriria hashear las contraseñas
#
# No agregue mas pues al menos a las preguntas creo que no le suma nada. No se si valdria un indice en alguna tabla
